# %% [markdown]
# # **INFORMATION**

# %% [markdown]
# ## Thông tin sinh viên
# - Lớp: DHKHMT19A
# - MSSV: 23722291
# - Họ tên: Cao Huỳnh Trung Kiên
# - Số máy: 15
# - Tên file: 2372291_CHTrungKien_M15.ipynb

# %% [markdown]
# # **DESCRIPTION**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score

# %% [markdown]
# # **CODE HERE**

# %% [markdown]
# ## **Data Preparation And Preprocessing**

# %%
# Đọc CSV
data = pd.read_csv('students_performance_practice.csv')

# %%
# Hiển thị thông tin cơ bản về dữ liệu
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             10000 non-null  int64
#  1   Age                   10000 non-null  int64
#  2   StudyHours            9500 non-null   float64
#  3   AttendanceRate        9500 non-null   float64
#  4   AssignmentsCompleted  10000 non-null  float64
#  5   OnlineActivity        9500 non-null   float64
#  6   SleepHours            10000 non-null  float64
#  7   SocialActivity        10000 non-null  float64
#  8   MidtermScore          10000 non-null  float64
#  9   FinalScore            10000 non-null  float64
#  10  GPA                   10000 non-null  float64
#  11  GradePoints           10000 non-null  float64
#  12  PerformanceIndex      10000 non-null  float64
#  13  Major                 10000 non-null  object
#  14  City                  10000 non-null  object
#  15  Gender                10000 non-null  object
# dtypes: float64(11), int64(2), object(3)
# memory usage: 1.2+ MB
# None

# %%
# Hiển thị 5 dòng đầu tiên của dữ liệu
data.head()
# Out:
#    StudentID  Age  StudyHours  AttendanceRate  AssignmentsCompleted  \
# 0          1   24        32.0            91.3                  59.1
# 1          2   21        15.5            78.4                  77.9
# 2          3   30        29.7            90.0                  67.2
# 3          4   28        30.0            89.8                  96.6
# 4          5   25         9.7            71.2                  89.1
#
#    OnlineActivity  SleepHours  SocialActivity  MidtermScore  FinalScore   GPA  \
# 0             7.7         5.8             2.9          71.2        92.8  3.67
# 1             6.3         6.2             0.2          59.8        82.2  2.94
# 2             6.2         8.1             2.2          65.5        93.9  3.61
# 3             4.5         6.1             0.0          61.5        87.0  3.74
# 4             5.9         7.6             3.1          58.0        76.4  3.20
#
#    GradePoints  PerformanceIndex Major     City  Gender
# 0        91.87             82.00    IT  Cần Thơ  Female
# 1        73.52             70.98    CE   Hà Nội    Male
# 2        90.34             79.68    SE   Hà Nội    Male
# 3        93.57             74.24    CS  Cần Thơ    Male
# 4        80.04             67.24    CS  Đà Nẵng    Male

# %%
# Loại bỏ các hàng bị thiếu dữ liệu của cột AttendanceRate 
data = data.dropna(subset=['AttendanceRate'])

# Điền giá trị thiếu của cột StudyHours và OnlineActivity bằng giá trị trung vị
data.fillna({
    'StudyHours': data['StudyHours'].median(),
    'OnlineActivity': data['OnlineActivity'].median()
}, inplace=True)

# data.fillna({
#     'StudyHours': data['StudyHours'].median(),
#     'OnlineActivity': data['OnlineActivity'].median(),
#     'AttendanceRate': data['AttendanceRate'].median()
# }, inplace=True)

# %%
# Tính ma trận tương quan
corr_matrix = data.select_dtypes(include=['int64', 'float64']).corr().round(2)

# In ra kết quả
corr_matrix
# Out:
#                       StudentID   Age  StudyHours  AttendanceRate  \
# StudentID                  1.00  0.01        0.01           -0.02
# Age                        0.01  1.00       -0.00           -0.00
# StudyHours                 0.01 -0.00        1.00            0.01
# AttendanceRate            -0.02 -0.00        0.01            1.00
# AssignmentsCompleted      -0.01 -0.01        0.02            0.02
# OnlineActivity             0.03 -0.01       -0.01            0.02
# SleepHours                 0.01  0.00       -0.02           -0.00
# SocialActivity             0.02 -0.01       -0.01            0.00
# MidtermScore               0.00  0.00        0.61            0.14
# FinalScore                 0.01 -0.00        0.73            0.23
# GPA                        0.01 -0.01        0.68            0.22
# GradePoints                0.01 -0.01        0.68            0.22
# PerformanceIndex           0.01 -0.00        0.74            0.21
#
#                       AssignmentsCompleted  OnlineActivity  SleepHours  \
# StudentID                            -0.01            0.03        0.01
# Age                                  -0.01           -0.01        0.00
# StudyHours                            0.02           -0.01       -0.02
# AttendanceRate                        0.02            0.02       -0.00
# AssignmentsCompleted                  1.00            0.01        0.00
# OnlineActivity                        0.01            1.00        0.01
# SleepHours                            0.00            0.01        1.00
# SocialActivity                        0.00           -0.00       -0.01
# MidtermScore                          0.02            0.00        0.00
# FinalScore                            0.02           -0.00       -0.00
# GPA                                   0.02           -0.00       -0.01
# GradePoints                           0.02           -0.00       -0.01
# PerformanceIndex                      0.03           -0.00       -0.00
#
#                       SocialActivity  MidtermScore  FinalScore   GPA  \
# StudentID                       0.02          0.00        0.01  0.01
# Age                            -0.01          0.00       -0.00 -0.01
# StudyHours                     -0.01          0.61        0.73  0.68
# AttendanceRate                  0.00          0.14        0.23  0.22
# AssignmentsCompleted            0.00          0.02        0.02  0.02
# OnlineActivity                 -0.00          0.00       -0.00 -0.00
# SleepHours                     -0.01          0.00       -0.00 -0.01
# SocialActivity                  1.00         -0.00       -0.03 -0.03
# MidtermScore                   -0.00          1.00        0.65  0.61
# FinalScore                     -0.03          0.65        1.00  0.94
# GPA                            -0.03          0.61        0.94  1.00
# GradePoints                    -0.03          0.61        0.94  1.00
# PerformanceIndex               -0.02          0.88        0.93  0.87
#
#                       GradePoints  PerformanceIndex
# StudentID                    0.01              0.01
# Age                         -0.01             -0.00
# StudyHours                   0.68              0.74
# AttendanceRate               0.22              0.21
# AssignmentsCompleted         0.02              0.03
# OnlineActivity              -0.00             -0.00
# SleepHours                  -0.01             -0.00
# SocialActivity              -0.03             -0.02
# MidtermScore                 0.61              0.88
# FinalScore                   0.94              0.93
# GPA                          1.00              0.87
# GradePoints                  1.00              0.87
# PerformanceIndex             0.87              1.00

# %%
plt.figure(figsize=(12, 8))  # kích thước hình
sns.heatmap(corr_matrix,
            annot=True,       # hiển thị số tương quan
            cmap="coolwarm",  # bảng màu dễ nhìn
            fmt=".2f",        # format 2 chữ số thập phân
            linewidths=0.5)   # đường ngăn ô

plt.title("Correlation Matrix", fontsize=16)
plt.show()

# %%
# Các cột có thuộc tính tuyến tính và không cần thiết
to_drop = ['GradePoints', 'PerformanceIndex', 'StudentID', 'Age', 'Major', 'City', 'Gender', 'GPA']

# Loai bỏ các cột này khỏi dữ liệu
X_train = data.drop(columns=to_drop)

# %%
# Các cột dạng object
categorical_cols = X_train.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# []

# %%
# Các cột dạng numeric sau khi loại bỏ
numeric_cols = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()
numeric_cols
# Out:
# ['StudyHours',
#  'AttendanceRate',
#  'AssignmentsCompleted',
#  'OnlineActivity',
#  'SleepHours',
#  'SocialActivity',
#  'MidtermScore',
#  'FinalScore']

# %%
# Tiền xử lý dữ liệu
preprocess = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(drop='first'), categorical_cols)
    ]
)

# %% [markdown]
# ## **KMeans Clustering**

# %%
# Xây dựng pipeline KMeans
pipe = Pipeline(steps=[
    ('prep', preprocess),
    ('kmeans', KMeans(n_clusters=4, random_state=42, n_init='auto'))
])

# Huấn luyện mô hình
pipe.fit(X_train)

# Lấy nhãn cluster sau khi huấn luyện
labels = pipe.named_steps['kmeans'].labels_

# Gán nhãn cụm vào dữ liệu gốc
data_final = X_train.copy()
data_final['Cluster'] = labels

# %%
# Thống kê số lượng sinh viên trong mỗi cụm
data_final['Cluster'].value_counts()
# Out:
# Cluster
# 3    2656
# 0    2594
# 2    2310
# 1    1940
# Name: count, dtype: int64

# %%
data_final
# Out:
#       StudyHours  AttendanceRate  AssignmentsCompleted  OnlineActivity  \
# 0           32.0            91.3                  59.1             7.7
# 1           15.5            78.4                  77.9             6.3
# 2           29.7            90.0                  67.2             6.2
# 3           30.0            89.8                  96.6             4.5
# 4            9.7            71.2                  89.1             5.9
# ...          ...             ...                   ...             ...
# 9995        28.6            96.9                  75.6             6.1
# 9996        28.6            74.8                  87.6             5.9
# 9997        37.5            82.0                  71.7             6.4
# 9998        33.8            94.9                  88.8             8.0
# 9999        18.3            85.0                  94.7             7.8
#
#       SleepHours  SocialActivity  MidtermScore  FinalScore  Cluster
# 0            5.8             2.9          71.2        92.8        0
# 1            6.2             0.2          59.8        82.2        2
# 2            8.1             2.2          65.5        93.9        0
# 3            6.1             0.0          61.5        87.0        3
# 4            7.6             3.1          58.0        76.4        1
# ...          ...             ...           ...         ...      ...
# 9995         5.3             2.3          74.0        88.1        0
# 9996         5.6             1.1          68.5       100.0        0
# 9997         7.2             3.2          58.2        96.2        0
# 9998         7.8             3.3          68.0       100.0        0
# 9999         8.0             0.7          65.2        81.6        3
#
# [9500 rows x 9 columns]

# %%
# Lưu data_final vào file TSV
data_final.to_csv('students_performance_clusters.tsv', sep='\t', index=False)

# %% [markdown]
# ## **Evaluate The Model**

# %%
# Lấy dữ liệu đã được biến đổi sau tiền xử lý
X_transformed = pipe.named_steps['prep'].transform(X_train)

# Tính silhouette score
sil_score = silhouette_score(X_transformed, labels)
print(f'Silhouette Score: {sil_score:.4f}')
# Out:
# Silhouette Score: 0.1041

# %%
# Sao chép dữ liệu gốc để phân tích thêm
data_analyzed = data.copy()

# Vẽ scatter (StudyHours vs FinalScore)
plt.figure(figsize=(8, 6))
plt.scatter(data_analyzed["StudyHours"], data_analyzed["FinalScore"], c=data_final["Cluster"], s=10)
plt.xlabel("Study Hours")
plt.ylabel("Final Score")
plt.title(f"Study Hours vs Final Score (colored by cluster K=4)")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## **Determine The Optimal Number Of Groups**

# %%
inertias = []
sil_scores = []
models = {}
K_range = range(2, 7)

for k in K_range:
    preprocess = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), numeric_cols),
            ('cat', OneHotEncoder(drop='first'), categorical_cols)
        ]
    )
    
    pipe_k = Pipeline(steps=[
        ('prep', preprocess),
        ('kmeans', KMeans(n_clusters=k, random_state=42, n_init='auto'))
    ])
    
    labels_k = pipe_k.fit_predict(X_train)
    models[k] = pipe_k
    inertias.append(pipe_k.named_steps['kmeans'].inertia_)
    sil_scores.append(silhouette_score(pipe_k.named_steps['prep'].transform(X_train), labels_k))

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(K_range, inertias, marker='o')
plt.title("Elbow Method")
plt.xlabel("K")
plt.ylabel("Inertia")
plt.grid(alpha=0.3)

plt.subplot(1,2,2)
plt.plot(K_range, sil_scores, marker='o')
plt.title("Silhouette Score")
plt.xlabel("K")
plt.ylabel("Score")
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

print("Inertia:", {k: round(v, 2) for k, v in zip(K_range, inertias)})
print("Silhouette:", {k: round(v, 2) for k, v in zip(K_range, sil_scores)})
# Out:
# Inertia: {2: 61359.13, 3: 57445.24, 4: 53755.44, 5: 50942.66, 6: 48928.24}
# Silhouette: {2: np.float64(0.17), 3: np.float64(0.11), 4: np.float64(0.1), 5: np.float64(0.1), 6: np.float64(0.1)}
